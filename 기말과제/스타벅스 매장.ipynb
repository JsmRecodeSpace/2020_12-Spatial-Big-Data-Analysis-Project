# %%
import pandas as pd
import numpy as np
import warnings; warnings.filterwarnings('ignore')
pd.set_option('max_rows', 1000, 'max_columns', 20)

# %%
star = pd.read_csv('스타벅스_20200721.csv', sep='|'); star
seoul_starbucks = star[:540]
seoul_starbucks = seoul_starbucks.drop_duplicates('Address')

# %%
seoul_starbucks.to_csv('seoul_starbucks2020.csv', encoding='cp949', index=False)

# %%
pd.read_csv('seoul_starbucks2020.csv', encoding='cp949')
# Out:
#      Seq       Sotre_nm                                            Address  \
# 0      1         신림사거리                          서울특별시 관악구 남부순환로 1619 (신림동)
# 1      2        신림역포도몰        서울특별시 관악구 신림로 330, PODO MALL 1층 101 일부 (신림동)
# 2      3            신림                           서울특별시 관악구 신림로 355-1 (신림동)
# 3      4        서울대입구역                          서울특별시 관악구 남부순환로 1812 (봉천동)
# 4      5          서울대역                          서울특별시 관악구 남부순환로 1817 (봉천동)
# 5      6      관악서울대입구R                             서울특별시 관악구 관악로 158 (봉천동)
# 6      7         보라매대교                  서울특별시 관악구 보라매로3길 23, 대교빌딩 1층 (봉천동)
# 7      8        보라매공원R          서울특별시 동작구 보라매로5길 35 (신대방동, 파크스퀘어,보라매현대APT)
# 8      9       신대방삼거리역                             서울특별시 동작구 상도로 102 (상도동)
# 9     10        숭실대입구역                             서울특별시 동작구 상도로 354 (상도동)
# 10    11       역삼아레나빌딩                             서울특별시 강남구 언주로 425 (역삼동)
# ...
